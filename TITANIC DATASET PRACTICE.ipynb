# %%
##MAKING A PANDAS PROFILE REPORT FOR BOTH DATASETS

import ydata_profiling as ypf
import pandas as pd
#Reading in both datasets
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

Profile = ypf.ProfileReport(train)

Profile.to_file("train.html")

#viewing the file
import os
import webbrowser

if os.path.isfile("train.html"):
    webbrowser.open_new_tab("train.html")
else:
    print("File not found")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Generating a pandas profile report for test dataset

profile = ypf.ProfileReport(test)
profile.to_file("test.html")

#viewing the profile

if os.path.isfile("test.html"):
    webbrowser.open_new_tab("test.html")
else:
    print("File not found")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Viewing the first ten lines of the test dataset

test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
#Viewing the last ten lines of the training dataset

train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#Writing a function to clean the data
#Objective of the training is to train the mode to predict those who would have survived as a result of Pclass.

train = train.drop(["Sex","SibSp","Ticket","Cabin","Embarked"], axis = 1)
    
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  Parch     Fare
# 0                            Braund, Mr. Owen Harris  22.0      0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0      0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0  53.1000
# 4                           Allen, Mr. William Henry  35.0      0   8.0500
# 5                                   Moran, Mr. James   NaN      0   8.4583
# ...

# %%
##Finding correlation
corr = train.corr(method = 'pearson')
corr
# Out:
#              PassengerId  Survived    Pclass       Age     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481 -0.077221  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.189119  0.096067
# Parch          -0.001652  0.081629  0.018443 -0.189119  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  0.096067  0.216225  1.000000

# %%
##Drawing a heatmap of train
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib qt

sns.heatmap(train.corr(method='pearson'))
plt.show()

# %%
#use mask to split the data
mask = train.Age==0
train[mask==True]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Age, Parch, Fare]
# Index: []

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  Parch     Fare
# 0                            Braund, Mr. Owen Harris  22.0      0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0      0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0  53.1000
# 4                           Allen, Mr. William Henry  35.0      0   8.0500
# 5                                   Moran, Mr. James   NaN      0   8.4583
# ...

# %%
##Replacing NaN values with zeros in the column age

train_filled = train.fillna(0)
train_filled.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  Parch     Fare
# 0                            Braund, Mr. Owen Harris  22.0      0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0      0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0  53.1000
# 4                           Allen, Mr. William Henry  35.0      0   8.0500
# 5                                   Moran, Mr. James   0.0      0   8.4583
# ...

# %%
##Replacing zeros in Age column with mean

train_1 = train_filled['Age'].mean()
train_1
# Out:
# 23.79929292929293

# %%
##Replacing nan values with mean

train['Age'].fillna(train_1, inplace = True)
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name        Age  Parch  \
# 0                            Braund, Mr. Owen Harris  22.000000      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      0
# 2                             Heikkinen, Miss. Laina  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      0
# 4                           Allen, Mr. William Henry  35.000000      0
# 5                                   Moran, Mr. James  23.799293      0
# 6                            McCarthy, Mr. Timothy J  54.000000      0
# ...

# %%
#Getting statistics of the dataset

train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   28.527099    0.381594   32.204208
# std     257.353842    0.486592    0.836071   13.213618    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   35.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    6.000000  512.329200

# %%
##Getting statistics of the filled dataset

train_filled.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.799293    0.381594   32.204208
# std     257.353842    0.486592    0.836071   17.596074    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   35.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    6.000000  512.329200

# %%
##Replacing the zeros in the column fare with mean value of the fares paid
#mean_fare= train['Fare'].mean()
#mean_fare

#train = train['Fare'].replace(0,mean_fare)
#train
train
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
train
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
train_filled
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  Parch     Fare
# 0                              Braund, Mr. Owen Harris  22.0      0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0  71.2833
# 2                               Heikkinen, Miss. Laina  26.0      0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0  53.1000
# 4                             Allen, Mr. William Henry  35.0      0   8.0500
# ...

# %%
mean_fare= train_filled['Fare'].mean()
mean_fare
# Out:
# 32.2042079685746

# %%
train_filled = train_filled['Fare'].replace(0,mean_fare)
train_filled
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#noticed the above command changes dataset into a single column.
train_filled
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
